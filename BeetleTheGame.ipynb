# %%
from random import randint

def beetle221():
    """Version of beetle game with statistics"""
    L = [0,0,0,0,0,0] # empty list which store our progress
    M = [1,1,2,2,1,6] # when L list reach these values then game stop
    C = [0,0,0,0,0,0] # list to store counters
    rolls = 0 # counts number of rolls
    # Few colours to make our progress in console more transparent
    a = "\033[1;32m" # green
    b = "\033[1;31m" # red
    c = "\033[1;33m" # yellow
    d = "\033[0;37m" # gray/grey
    e = "\033[1;34m" # blue
    z = "\033[0m" # neutral
    print(e+"Welcome to the game!") # inital comment, for start recognition
    print("Let's start. Good luck!"+z)
    keep_going = True # condition to keep game run
    while (keep_going): 
        if L != M:  # comparing lists, if satisfied then roll
            rolls += 1 # adding rolls
            roll = randint(1, 6) # range of rolls that we use to play
            print("You rolled: %i"  % roll)
            if roll == 1: # need to roll 1 to get 2 or 6
                C[0] += 1 # adding particular rolled value to list
                if L[0] < M[0]: # add body if roll 1 and don"t have body yet 
                    L[0] += 1
                    print(a+"You get a body! "
                          "Now you can get a head or legs!"+z)
                elif L[0] == M[0]: # if already have a body then do nothing.
                    print(c+"You already have a body! Roll another value."+z)
            elif roll == 2: # need to roll 2 to get 3, 4 or 5
                C[1] += 1 # adding particular rolled value to list
                if L[0] != M[0]: # if don"t have body yet do nothing
                    print(b+"You can't get a head before you will get a body."
                          " Roll another value."+z)
                elif (L[0] == 1) and (L[1] < M[1]):
                # if have a body then add a head till get 1
                    L[1] += 1 # adding particular rolled value to list
                    print(a+"You get a head! Now you can get an antenna," 
                          " an eye and a mouth!" +z)
                elif L[1] == M[1]: # if already have a head then do nothing.
                    print(c+"You already have a head. Roll another value."+z)
            elif roll == 3: # if 1 & 2 satisfied then can add 3
                C[2] += 1 # adding particular rolled value to list
                if L[0] == 0 or L[1] == 0: # if 1 and 2 not satisfied 
                # then do nothing
                    print(b+"You can't get an antenna before you will get" 
                          " a head. Roll another value."+z)
                elif (L[1] == M[1]) and (L[2] < M[2]):
                # if have a head then add an antennas till get 2 of them
                    L[2] += 1
                    print(a+"You get an antenna!"+z)
                elif L[2] == M[2]: # if already have both antennas
                # then do nothing.
                    print(c+"You already have both antennas."
                          " Roll another value."+z)
            elif roll == 4:
                C[3] += 1 # adding particular rolled value to list
                if L[0] == 0 or L[1] == 0:
                # if 1 and 2 not satisfied then do nothing
                    print(b+"You can't get an eye before you will get head."
                          " Roll another value."+z)
                elif (L[1] == M[1]) and (L[3] < M[3]):
                # if have a body then add a head till get 1
                    L[3] += 1
                    print(a+"You get an eye!"+z)
                elif L[3] == M[3]: # if already have both eyes then do nothing.
                    print(c+"You already have both eyes."
                          " Roll another value."+z)
            elif roll == 5:
                C[4] += 1 # adding particular rolled value to list
                if L[0] == 0 or L[1] == 0:
                # if 1 and 2 not satisfied then do nothing
                    print(b+"You can't get a mouth before you will get head."
                          " Roll another value."+z)
                elif (L[1] == M[1]) and (L[4] < M[4]): # if have head 
                # then add mouth 
                    L[4] += 1
                    print(a+"You get a mouth!"+z)
                elif L[4] == M[4]: # if already have a mouth then do nothing.
                    print(c+"You already have a mouth. Roll another value."+z)
            elif roll == 6:
                C[5] += 1 # adding particular rolled value to list
                if L[0] == 0: # if 1 not satisfied then do nothing
                    print(b+"You can't get a leg before you will get body!"
                          " Roll another value."+z)
                elif (L[0] == M[0]) and (L[5] < M[5]):
                    # if 1 satisfied then can add 6
                    L[5] += 1
                    print(a+"You get a leg!"+z)
                elif L[5] == M[5]: # if already all eyes then do nothing.
                    print(c+"You already have all legs. Roll another value."+z)
            print(d + "Your stack:"+ z, L) # new value pop up if valid
        elif L == M: # 
            print(e+" It was a last roll, well done 🐞", "\n",
                  "Player has collected all body parts", L, "\n",
                  "Here is summary of your rolls:", C, "\n", 
                  "In total you rolled your dice", rolls, "times.","\n",
                  "Odd rolls:", C[0] + C[2] + C[4],
                  "Even rolls:", (C[1] + C[3] + C[5]))
            keep_going = False # condition to stop the game          

beetle221()
# Out:
# Welcome to the game!
# Let's start. Good luck!
# You rolled: 5
# You can't get a mouth before you will get head. Roll another value.
# Your stack: [0, 0, 0, 0, 0, 0]
# You rolled: 4
# You can't get an eye before you will get head. Roll another value.
# Your stack: [0, 0, 0, 0, 0, 0]
# You rolled: 2
# You can't get a head before you will get a body. Roll another value.
# Your stack: [0, 0, 0, 0, 0, 0]
# You rolled: 5
# You can't get a mouth before you will get head. Roll another value.
# Your stack: [0, 0, 0, 0, 0, 0]
# You rolled: 5
# You can't get a mouth before you will get head. Roll another value.
# Your stack: [0, 0, 0, 0, 0, 0]
# You rolled: 1
# You get a body! Now you can get a head or legs!
# Your stack: [1, 0, 0, 0, 0, 0]
# You rolled: 6
# You get a leg!
# Your stack: [1, 0, 0, 0, 0, 1]
# You rolled: 5
# You can't get a mouth before you will get head. Roll another value.
# Your stack: [1, 0, 0, 0, 0, 1]
# You rolled: 2
# ...

# %%
def beetle222():
    """In this version of game we have to collect 2 beetles."""
    L1 = [0,0,0,0,0,0] # empty list to store our progress of first beetle
    L2 = [0,0,0,0,0,0] # empty list to store our progress of second beetle
    M = [1,1,2,2,1,6] # when L2 list reach these values then game stop
    C = [0,0,0,0,0,0] # list to store counters
    rolls = 0 # summarise number of rolls
    # a few colours to make our progress in console more transparent:
        # green colors - boogie
        # red colors - woogie
        # grey colors - you get enough of these parts
        # dim colors - can't apply body part yet.
    Y = "\033[0;31m" # red colour for console displaying
    G = "\033[0;32m" # green colour for console displaying
    W = "\033[0;00m" # custom colour console displaying
    Z = "\033[0;37m" # gray colour for console displaying
    r = "\033[1;31m" # red for positive displaying
    g = "\033[1;32m" # green for positive displaying
    B = "\033[1;34m" # blue color for final printout
    b = "\033[0;35m" # violet color for final printout
    print(B+" Welcome to the game Beetles 0.2!","\n",
          "In this version player collects all body parts of 2 beetles!"
          "\n","🐞 #1 is called Boogie, 🐞 #2 is called Woogie","\n",
          "Below you can see:","\n",
          "Rolled value, Game progress for Boogie and Woogie, Roll counter"+W)
    keep_going = True
    while(keep_going):
        if L2 != M:
            roll = randint(1,6)
            rolls += 1
            # Below you can see: rolled value, 1st and 2nd bug progress, 
            # total number of rolls
            print("Player rolled: %i" % roll,"B:", L1, "W:", L2,
                  "TR: #", rolls)
            if roll == 1: # need to get 1 to get 2 or 6
                C[0] += 1
                if L1[0] < M[0]: 
                    L1[0] += 1
                    print(g+"Boogie gets a body! "
                          "Now Boogie can get a head or legs."+W)
                elif L1[0] == M[0] and L2[0] < M[0]:
                    L2[0] += 1
                    print(r+"Woogie gets a body! "
                          "Now you can get a head or legs."+W)
                else:
                    print(Z+"Both bugs have a bodies. "
                          "Try to roll another value."+W)
            elif roll == 2: # need to get 2 to get 3, 4 or 5
                C[1] += 1
                if L1[0] != M[0] or L2[0] != M[0]:
                    print(G+"Boogie can't get a head before will get a body. "
                          "Try to roll another value."+W)
                elif L1[0] == M[0] and L1[1] < M[1]:
                    L1[1] += 1
                    print(g+"Boogie gets a head! Now Boogie can get "
                          "an antenna, an eye and a mouth!"+W)
                elif L1[1] == M[1] and L2[1] < M[1]:
                    L2[1] += 1
                    print(r+"Woogie gets a head! Now Woogie can get "
                          "an antenna, an eye and a mouth!"+W)
                elif L1[1] == M[1] and L2[0] != M[0]:
                    print(Y+"Woogie needs a body first to get a head. "+W)
                elif L2[1] == M[1]:
                    print(Z+"Both bugs have heads. "
                          "Try to roll another value."+W)
            elif roll == 3:
                C[2] += 1
                if L1[0] != M[0] or L1[1] != M[1]:
                    print(G+"Boogie can't get an antenna before will get "
                          "a body. Try to roll another value."+W)
                elif L1[1] == M[1] and L1[2] < M[2]:
                    L1[2] += 1
                    print(g+"Boogie gets an antenna!"+W)
                elif L1[1] == M[1] and L2[1] == M[1] and L2[2] < M[2]:
                    L2[2] += 1
                    print(r+"Woogie gets an antenna!"+W)
                elif L1[2] == M[2] and L2[1] != M[1]:
                    print(Y+"Woogie needs a head first to get an antenna. "+W)
                elif L2[2] == M[2]:
                    print(Z+"Both bugs have antennas. "
                          "Try to roll another value."+W)
            elif roll == 4:
                C[3] += 1
                if L1[0] != M[0] or L1[1] != M[1]:
                    print(G+"Boogie can't get an eye before will get a "
                          "body. Try to roll another value."+W)
                elif L1[1] == M[1] and L1[3] < M[3]:
                    L1[3] += 1
                    print(g+"Boogie gets an eye!"+W)
                elif L1[1] == M[1] and L2[1] == M[1] and L2[3] < M[3]:
                    L2[3] += 1
                    print(r+"Woogie gets an eye!"+W)
                elif L1[3] == M[3] and L2[1] != M[1]:
                    print(Y+"Woogie needs a head first to get another eye."+W)
                elif L2[3] == M[3]:
                    print(Z+"Both bugs have all eyes. " 
                          "Try to roll another value."+W)
            elif roll == 5:
                C[4] += 1
                if L1[0] != M[0] or L1[1] != M[1]:
                    print(G+"Boogie can't get a mouth before will get a "
                          "body. Try to roll another value."+W)
                elif L1[1] == M[1] and L1[4] < M[4]:
                    L1[4] += 1
                    print(g+"Boogie gets a mouth!"+W)
                elif L1[4] == M[4] and L2[1] == M[1] and L2[4] < M[4]:
                    L2[4] += 1
                    print(r+"Woogie gets a mouth!"+W)
                elif L1[4] == M[4] and L2[1] != M[1]:
                    print(Y+"Woogie needs a head first to get mouth."+W)  
                elif L2[4] == M[4]:
                    print(Z+"Both bugs have mouths. "
                          "Try to roll another value."+W)
            elif roll == 6: 
                C[5] += 1
                if L1[0] != M[0]:
                    print(G+"Boogie can't get a leg before will get a "
                          "body! Try to roll another value."+W)
                elif L1[0] == M[0] and L1[5] < M[5]:
                    L1[5] += 1
                    print(g+"Boogie gets a leg!"+W)
                elif L2[0] == M[0] and L2[5] < M[5]:
                    L2[5] += 1
                    print(r+"Woogie gets a leg!"+W)
                elif L1[5] == M[5] and L2[0] != M[0]:
                    print(Y+"Woogie needs a body first to get another leg."+W)  
                elif L2[5] == M[5]:
                    print(Z+"Both bugs have all legs> "
                          "Try to roll another value."+W)
        elif L2 == L1:
            print(B+" It was the last roll, game over!", "\n",
                "You have collected all body parts for both of your beetles!",
                  "\n", g+"🐞", L1, ""+W, r+"🐞", L2, ""+W, b+ 
                "\n","Here is summary of your rolls:", C, "\n",
                "In total player rolled your dice:", rolls, "times.",
                "Odd rolls:", C[0] + C[2] + C[4], "Even rolls:",
                C[1] + C[3] + C[5])
            keep_going = False

beetle222()
# Out:
#  Welcome to the game Beetles 0.2!
#  In this version player collects all body parts of 2 beetles!
#  🐞 #1 is called Boogie, 🐞 #2 is called Woogie
#  Below you can see:
#  Rolled value, Game progress for Boogie and Woogie, Roll counter
# Player rolled: 2 B: [0, 0, 0, 0, 0, 0] W: [0, 0, 0, 0, 0, 0] TR: # 1
# Boogie can't get a head before will get a body. Try to roll another value.
# Player rolled: 4 B: [0, 0, 0, 0, 0, 0] W: [0, 0, 0, 0, 0, 0] TR: # 2
# Boogie can't get an eye before will get a body. Try to roll another value.
# Player rolled: 3 B: [0, 0, 0, 0, 0, 0] W: [0, 0, 0, 0, 0, 0] TR: # 3
# Boogie can't get an antenna before will get a body. Try to roll another value.
# Player rolled: 3 B: [0, 0, 0, 0, 0, 0] W: [0, 0, 0, 0, 0, 0] TR: # 4
# Boogie can't get an antenna before will get a body. Try to roll another value.
# Player rolled: 2 B: [0, 0, 0, 0, 0, 0] W: [0, 0, 0, 0, 0, 0] TR: # 5
# Boogie can't get a head before will get a body. Try to roll another value.
# ...

# %%
def beetle223():
    """Version of game for 2 players "L" and "N":
    Game is stopped when one of players collects all body parts of beetle,
    but then second player still has a right to roll a dice.
    """
    L = [0,0,0,0,0,0] # empty input list which store 1st player progress
    N = [0,0,0,0,0,0] # empty input list which store 2nd player progress
    M = [1,1,2,2,1,6] # after reaching this list for one of players game stop
    CL = [0,0,0,0,0,0] # list to store counters
    CN = [0,0,0,0,0,0] # list to store counters
    RL = 0 # roll counter for 1st player, below is roll counter for 2nd player
    RN = 0 # names changed to avoid confusion with roll as ro11 or roII.
    R = 0 # names changed to avoid confusion with roll as ro11 or roII.
    # Few colours to make our progress in console more transparent
    # all colors stored as lower characters
    # 1st player red/green
    # 2nd player blue/yellow
    e = "\033[0;31m" # red
    g = "\033[1;32m" # green
    r = "\033[1;31m" # dimred
    n = "\033[0;32m" # dimgreen
    b = "\033[1;34m" # blue
    d = "\033[1;36m" # dimblue
    s = "\033[0;34m" # sparkblue
    y = "\033[1;33m" # yellow
    w = "\033[1;37m" # white
    x = "\033[0;30m" # black
    keep_going = True # condition to keep game run
    print(x+"Welcome to the game - beetle for 2 players!")
    # inital comment, for start recognition
    print("Let's start. Good luck!","\n", "Below you can see:","\n",
          "Rolled value, Roll counter","\n","Comment regarding rolled value",
          "\n", "Game progress by player" +w)
    while(keep_going):
        if L == M or N == M:
            keep_going = False
            print(x+"It was the last body part!", "\n",
                  "Here are the game statistics:", "\n",
                  r+"Player L stack:", L,"\n", 
                  "Summary of player L rolls:", CL, "\n",
                  "Odd rolls:", CL[0] + CL[2] + CL[4], "Even rolls:", 
                  CL[1] + CL[3] + CL[5],"\n", 
                  b+"Player N stack:", N,"\n",
                  "Summary of player L rolls:",CN, "\n", 
                  "Odd rolls:", CN[0] + CN[2] + CN[4], "Even rolls:", 
                  CN[1] + CN[3] + CN[5],"" +w)
            if L == M and N == M:
                print("\n","Both players won!"+w, "\n",
                      "Total number of rolls:", RL, "=", RN) 
                # important as this can happened if both players have right
                # to play the same number of turns
                print(L, N)
            elif L == M:
                print(r+"\n","L🐞 wins :)"+w, "Total number of rolls:", RL)
            elif N == M:
                print(b+"\n","N🐞 wins :)"+w, "Total number of rolls:", RN)
        else: 
            if L != M:
                R = randint(1,6) # value of 
                RL += 1
                print(r+"L rolled: %i"%R,"#",RN,"" +w)
                if R == 1:
                    CL[0] += 1
                    if (L[0] < M[0]): 
                        L[0] += 1
                        print(g+"L gets a body! Now try gets head or legs!"+w)
                    elif (L[0] == M[0]):
                        print(n+"L already has a body!")
                        print("Try to roll another value."+w)
                elif R == 2:
                    CL[1] += 1
                    if (L[0] != M[0]):
                        print(e+"L can't get head before will get body!")
                        print("Try to roll another value."+w)
                    elif (L[0]==1) and (L[1]<M[1]):
                        L[1] += 1
                        print(g+"L gets a head!")
                        print("Now try gets antenna, eyes and mouth!"+w)
                    elif (L[1] == M[1]):
                        print(n+"L already has a head!")
                        print("Try to roll another value."+w)
                elif R == 3:
                    CL[2] += 1
                    if (L[0]==0 or L[1]==0):
                        print(e+"L can't get antenna before will get head!")
                        print("Try to roll another value."+w)
                    elif (L[1] == M[1]) and (L[2] < M[2]):
                        L[2] += 1
                        print(g+"L gets an antenna!"+w)
                    elif (L[2] == M[2]):
                        print(n+"L already has antenna!")
                        print("Try to roll another value."+w)
                elif R == 4:
                    CL[3] += 1
                    if (L[0]==0 or L[1]==0):
                        print(e+"L can't get eye before will get head!")
                        print("Try to roll another value."+w)
                    elif (L[1] == M[1]) and (L[3] < M[3]):
                        L[3] += 1
                        print(g+"L gets an eye!"+w)
                    elif (L[3] == M[3]):
                        print(n+"L already has eye!")
                        print("Try to roll another value."+w)
                elif R == 5:
                    CL[4] += 1
                    if (L[0]==0 or L[1]==0):
                        print(e+"You can't get mouth before will get head!")
                        print("Try to roll another value."+w)
                    elif (L[1] == M[1]) and (L[4] < M[4]):
                        L[4] += 1
                        print(g+"L gets a mouth!"+w)
                    elif (L[4] == M[4]):
                        print(n+"L already has mouth!")
                        print("Try to roll another value."+w)
                elif R == 6: 
                    CL[5] += 1
                    if (L[0] == 0):
                        print(e+"L can't get leg before will get body!")
                        print("Try to roll another value."+w)
                    elif (L[0] == M[0]) and (L[5] < M[5]):
                        L[5] += 1                
                        print(g+"L gets a leg!"+w)
                    elif (L[5] == M[5]):
                        print(n+"L already has all legs!")
                        print("Try to roll another value."+w)
                print(r+"L stack:",L,""+w)
            if N != M:
                R = randint(1,6)
                RN += 1
                print(b+"N rolled: %i"%R,"#",RN,"" +w)
                if R == 1:
                    CN[0] += 1
                    if (N[0] < M[0]): 
                        N[0] += 1
                        print(d+"N gets a body! Now try gets head or legs!"+w)
                    elif (N[0] == M[0]):
                        print(y+"N already has a body!")
                        print("Try to roll another value."+w)
                elif R == 2:
                    CN[1] += 1
                    if (N[0] != M[0]):
                        print(s+"N can't get head before will get body!")
                        print("Try to roll another value."+w)
                    elif (N[0]==1) and (N[1]<M[1]):
                        N[1] += 1
                        print(d+"N gets a head!")
                        print("Now can get antenna, eyes and mouth!"+w)
                    elif (N[1] == M[1]):
                        print(y+"N already has a head!")
                        print("Try to roll another value."+w)
                elif R == 3:
                    CN[2] += 1
                    if (N[0]==0 or N[1]==0):
                        print(s+"N can't get antenna before will get head!")
                        print("Try to roll another value."+w)
                    elif (N[1] == M[1]) and (N[2] < M[2]):
                        N[2] += 1
                        print(d+"N gets an antenna!"+w)
                    elif (N[2] == M[2]):
                        print(y+"N already has antenna!")
                        print("Try to roll another value."+w)
                elif R == 4:
                    CN[3] += 1
                    if (N[0]==0 or N[1]==0):
                        print(s+"N can't get eye before will get head!")
                        print("Try to roll another value."+w)
                    elif (N[1] == M[1]) and (N[3] < M[3]):
                        N[3] += 1
                        print(d+"N gets an eye!"+w)
                    elif (N[3] == M[3]):
                        print(y+"N already has eye!")
                        print("Try to roll another value."+w)
                elif R == 5:
                    CN[4] += 1
                    if (N[0]==0 or N[1]==0):
                        print(s+"N can't get mouth before will get head!")
                        print("Try to roll another value."+w)
                    elif (N[1] == M[1]) and (N[4] < M[4]):
                        N[4] += 1
                        print(d+"N gets a mouth!"+w)
                    elif (N[4] == M[4]):
                        print(y+"N already has mouth!")
                        print("Try to roll another value."+w)
                elif R == 6: 
                    CN[5] += 1
                    if (N[0] == 0):
                        print(s+"N can't get leg before will get body!")
                        print("Try to roll another value."+w)
                    elif (N[0] == M[0]) and (N[5] < M[5]):
                        N[5] += 1                
                        print(d+"N gets a leg!"+w)
                    elif (N[5] == M[5]):
                        print(y+"N already has all legs!")
                        print("Try to roll another value."+w)   
                print(b+"N stack:",N,""+w)
              
beetle223()
# Out:
# Welcome to the game - beetle for 2 players!
# Let's start. Good luck!
#  Below you can see:
#  Rolled value, Roll counter
#  Comment regarding rolled value
#  Game progress by player
# L rolled: 2 # 0
# L can't get head before will get body!
# Try to roll another value.
# L stack: [0, 0, 0, 0, 0, 0]
# N rolled: 3 # 1
# N can't get antenna before will get head!
# Try to roll another value.
# N stack: [0, 0, 0, 0, 0, 0]
# L rolled: 4 # 1
# L can't get eye before will get head!
# Try to roll another value.
# L stack: [0, 0, 0, 0, 0, 0]
# N rolled: 1 # 2
# N gets a body! Now try gets head or legs!
# N stack: [1, 0, 0, 0, 0, 0]
# L rolled: 5 # 2
# You can't get mouth before will get head!
# Try to roll another value.
# L stack: [0, 0, 0, 0, 0, 0]
# N rolled: 2 # 3
# N gets a head!
# Now can get antenna, eyes and mouth!
# N stack: [1, 1, 0, 0, 0, 0]
# L rolled: 5 # 3
# You can't get mouth before will get head!
# Try to roll another value.
# L stack: [0, 0, 0, 0, 0, 0]
# N rolled: 6 # 4
# ...
